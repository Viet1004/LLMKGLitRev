# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from IPython.display import Image, display
from llmkglitrev.agents.research_agents import research_agent
from langchain_core.messages import HumanMessage, SystemMessage, BaseMessage
# Show the agent
# display(Image(research_agent.get_graph().draw_mermaid_png()))
research_agent.get_graph().print_ascii()
# Out:
#                +-----------+
#                | __start__ |
#                +-----------+
#                      *
#                      *
#                      *
#           +---------------------+
#           | researcher_llm_call |
#           +---------------------+
#              ***            ...
#            **                  ..
#          **                      ..
# +-----------+           +----------------------+
# | tool_node |           | research_formulation |
# +-----------+           +----------------------+
#                                     *
#                                     *
#                                     *
#                               +---------+
#                               | __end__ |
#                               +---------+

# %%
from utils import show_prompt
from llmkglitrev.agents.prompts.research_planning import plan_research_system_message, plan_research_human_message
from llmkglitrev.agents.prompts.research_summary import research_agent_prompt
show_prompt(research_agent_prompt, "Research Agent Instructions")
# Out:
# ╭────────────────────────────────────────── Research Agent Instructions ──────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │      Role: You are an experienced researcher. Your job is to suggest a research plan for another researcher to  │
# │  conduct a research idea.                                                                                       │
# │      For context, today's date is {date}.                                                                       │
# │                                                                                                                 │
# │      You will be provided with following information:                                                           │
# ...

# %%
from llmkglitrev.samples.samples import sample_2
research_agent.invoke({"researcher_messages": [HumanMessage(content=sample_2)]})
# Out:
# {'research_plan': '**List of Queries and Tool Calls Made**\n\n1. Initial search query on the combination of federated learning, anomaly detection, mobile traffic, and privacy-preservation: "recent research mobile network traffic anomaly detection federated learning privacy preserving"\n   - **Findings**:\n     - Source 1: "Federated Learning for Privacy-Preserving Network Optimization"\n       - Federated learning is applied to optimize wireless communication networks while preserving user privacy.\n       - Method involves leveraging federated learning for distributed, privacy-preserving optimization tasks in complex wireless networks.\n       - Source: https://eureka.patsnap.com/article/federated-learning-for-privacy-preserving-network-optimization\n\n     - Source 2: "Privacy-Preserving Detection of Tampered Radio Through Federated Learning"\n       - Federated learning enables the detection of tampered transmissions in LoRa networks while preserving privacy.\n       - Source: htt
# ...
