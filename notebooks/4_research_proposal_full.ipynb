# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from IPython.display import Image, display
from llmkglitrev.agents.research_proposal_generator import proposal_generator_agent
from langchain_core.messages import HumanMessage, SystemMessage, BaseMessage
# Show the agent
# display(Image(proposal_generator_agent.get_graph().draw_mermaid_png()))
proposal_generator_agent.get_graph().print_ascii()
# Out:
#        +-----------+
#        | __start__ |
#        +-----------+
#               *
#               *
#               *
#     +-----------------+
#     | format_question |
#     +-----------------+
#               *
#               *
#               *
#   +---------------------+
#   | supervisor_subgraph |
#   +---------------------+
#               *
#               *
#               *
# +-------------------------+
# | final_research_proposal |
# +-------------------------+
#               *
#               *
#               *
#         +---------+
#         | __end__ |
#         +---------+

# %%
# Run the multi-agent supervisor agent
from utils import format_messages
from langchain_core.messages import HumanMessage
from llmkglitrev.samples import sample_1, sample_2
from llmkglitrev.agents.research_proposal_generator import proposal_generator_agent
from llmkglitrev.agents.states import AgentState, SupervisorState
# result = await proposal_generator_agent.ainvoke(
#     {"supervisor_messages": [HumanMessage(content=f"{sample_2}.")],
#     "research_topic": "Forecasting in Traffic/Network",
#     "raw_notes": [],
#     "notes": [],
#     "final_proposal":""})
result = await proposal_generator_agent.ainvoke(
    {"messages": [HumanMessage(content=f"{sample_2}.")]
    #  "research_topic": "Forecasting in Traffic/Network"
    }
)
# format_messages(result['final_proposal'])

# %%
format_messages(result["messages"])
# Out:
# ╭─────────────────────────────────────────────────── 🧑 Human ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │     Researcher A has expertise in time series, federated learning, machine learning. Here is his past research: │
# │     - Privacy-preserving federated learning for residential short-term load forecasting                         │
# │     - Secure federated learning for residential short term load forecasting                                     │
# │     - Bridging Smart Meter Gaps: A Benchmark of Statistical, Machine Learning and Time Series Foundation Models │
# │ for Data Imputation                                                                                             │
# │     - Towards a peer-to-peer residential short-term load forecasting with federated learning                    │
# │     - Spatiotemporal Graph Neural Networks in short term load forecasting: Does adding Graph Structure in       │
# │ Consumption Data Improve Predictions?                                                                           │
# │                                                                                                                 │
# │     He wants to collaborate and do research on anomaly detection in mobile traffic                              │
# │     Please propose a research idea that suits his past research and match with the topic he want to contributes │
# │ to                                                                                                              │
# │     .                                                                                                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────── 🧑 Human ────────────────────────────────────────────────────╮
# │ Here is the final proposal: # A Research Proposal: Federated Spatiotemporal Anomaly Detection for Mobile        │
# │ Network Traffic                                                                                                 │
# │                                                                                                                 │
# │ ## 1/ Research Motivation                                                                                       │
# │                                                                                                                 │
# │ The exponential growth of mobile data traffic, driven by ubiquitous smart devices and emerging applications     │
# │ like IoT and AR/VR, presents significant challenges for network operators. Ensuring network reliability,        │
# │ security, and quality of service requires sophisticated monitoring systems capable of identifying anomalous     │
# │ behavior. Anomalies in mobile traffic can signal critical issues such as network failures, security breaches    │
# │ (e.g., DDoS attacks, botnet activity), unexpected congestion, or even large-scale public events.                │
# │                                                                                                                 │
# │ However, developing effective anomaly detection systems for mobile networks is inherently complex due to the    │
# │ unique characteristics of the data. Mobile traffic exhibits strong **temporal patterns** (daily, weekly, and    │
# │ seasonal cycles), intricate **spatial dependencies** influenced by network topology and user mobility, and is   │
# │ often subject to **privacy regulations** that restrict the centralization of sensitive user data. Furthermore,  │
# │ real-world data collection is prone to **missing or incomplete records** due to sensor failures or transmission │
# │ errors. Current centralized detection models often struggle with these combined challenges, creating a pressing │
# │ need for a novel, privacy-preserving, and robust framework that can leverage the full spatiotemporal structure  │
# │ of mobile data without compromising user privacy.                                                               │
# │                                                                                                                 │
# │ ## 2/ Related Work and Research Gap                                                                             │
# │                                                                                                                 │
# │ Existing research on mobile traffic anomaly detection can be broadly categorized, each with notable             │
# │ limitations.                                                                                                    │
# │                                                                                                                 │
# │ *   **Centralized Temporal Models:** Traditional methods like ARIMA, LSTMs, and Transformers are applied to     │
# │ aggregated time series data from network nodes [1]. While effective at capturing temporal patterns, they        │
# │ typically ignore the spatial correlations between neighboring cells or base stations, leading to suboptimal     │
# │ detection of spatially propagating anomalies.                                                                   │
# │ *   **Spatiotemporal Graph Models:** Recent advances employ Graph Neural Networks (GNNs) to model the network   │
# │ as a graph, where nodes represent base stations and edges represent geographical or traffic-flow relationships. │
# │ Models like Graph WaveNet and MTGNN have shown promise in spatiotemporal forecasting [2]. However, their        │
# │ application to anomaly detection usually requires centralized data collection, which conflicts with growing     │
# │ data privacy concerns and regulations like GDPR.                                                                │
# │ *   **Federated Learning (FL) for Networking:** FL has been explored for various network management tasks,      │
# │ including intrusion detection and resource allocation [3]. Standard FL approaches (e.g., FedAvg) train a global │
# │ model by aggregating model updates from distributed nodes. While this preserves raw data locality, it is not    │
# │ inherently designed for modeling the complex *spatial dependencies* between different participants (e.g.,       │
# │ between telecom operators or regional data centers).                                                            │
# │ *   **Federated Graph Learning:** A nascent field explores training GNNs in a federated setting. Some           │
# │ approaches focus on vertically partitioned graphs or subgraph federated learning [4]. However, applying these   │
# │ directly to mobile networks is non-trivial. The spatial graph topology (which base station is adjacent to       │
# │ which) is often non-private and can be shared, but the dynamic traffic features on those nodes are private and  │
# │ must remain decentralized.                                                                                      │
# │                                                                                                                 │
# │ **Identified Research Gap:** There is a conspicuous lack of a unified framework that simultaneously addresses:  │
# │ 1) the joint learning of temporal and spatial dependencies for accurate anomaly detection, 2) strict data       │
# │ privacy through federated learning, and 3) robustness to real-world data imperfections like missing values.     │
# │ Most prior work optimizes for one or two of these objectives, but not all three in an integrated manner         │
# │ tailored for mobile network data.                                                                               │
# │                                                                                                                 │
# │ ## 3/ Proposed Method and Research Questions                                                                    │
# │                                                                                                                 │
# │ Leveraging the researcher's expertise, we propose a novel framework: **Federated Spatiotemporal Graph           │
# │ Imputation and Anomaly Detection (Fed-STGIAD)**. This framework is designed to perform accurate anomaly         │
# │ detection directly on decentralized, potentially incomplete mobile traffic data.                                │
# │                                                                                                                 │
# │ **Core Methodology:**                                                                                           │
# │ The proposed method consists of two co-designed components operating within a federated learning paradigm:      │
# │ 1.  **A Federated Spatiotemporal Graph Imputation Module:** This module addresses missing data. Using a shared  │
# │ graph structure (non-private network topology), each client (e.g., a regional server) trains a local GNN-based  │
# │ imputer (e.g., using Graph Attention Networks or Diffusion Convolutional Networks) on its local time series. A  │
# │ central server aggregates these local imputer models to create a global imputer that can infer missing values   │
# │ by leveraging learned spatial correlations from across the federation, without sharing raw traffic data.        │
# │ 2.  **A Federated Spatiotemporal Anomaly Detector:** This is the main detection model. It will be a graph-based │
# │ sequential model (e.g., a GNN coupled with a temporal convolutional network or a recurrent module). It will be  │
# │ trained directly on the decentralized data. Crucially, to capture cross-client spatial dependencies—essential   │
# │ for detecting anomalies that propagate across administrative boundaries—the federated aggregation step must be  │
# │ enhanced. Instead of simple averaging (FedAvg), we will explore **peer-to-peer federated learning** strategies  │
# │ or **topology-aware model aggregation** that weights updates based on the shared graph adjacency, aligning with │
# │ the researcher's expertise in peer-to-peer FL.                                                                  │
# │                                                                                                                 │
# │ **Key Research Questions:**                                                                                     │
# │ *   RQ1: How can a graph neural network be effectively trained for spatiotemporal imputation in a federated     │
# │ setting where the graph structure is global but node features are private and distributed?                      │
# │ *   RQ2: What federated aggregation strategy (e.g., topology-aware averaging, peer-to-peer gossip protocols)    │
# │ most effectively enables a global anomaly detection model to learn cross-client spatial dependencies while      │
# │ maintaining privacy?                                                                                            │
# │ *   RQ3: Does the joint optimization of imputation and anomaly detection in a federated framework lead to more  │
# │ robust and accurate anomaly detection compared to treating these as separate, sequential tasks?                 │
# │ *   RQ4: How does the proposed framework perform against state-of-the-art centralized and privacy-agnostic      │
# │ baselines on real-world mobile traffic datasets with simulated missing data and injected anomalies?             │
# │                                                                                                                 │
# │ ## 4/ Contrast to Previous Research                                                                             │
# │                                                                                                                 │
# │ The proposed Fed-STGIAD framework fundamentally differs from and advances prior work in several key aspects:    │
# │                                                                                                                 │
# │ *   **Vs. Centralized Spatiotemporal Models (e.g., [2]):** Our approach eliminates the need for a central data  │
# │ repository, offering a principled privacy-preserving alternative. This makes it viable in modern regulatory     │
# │ environments and for cross-operator collaboration, which is infeasible for centralized models.                  │
# │ *   **Vs. Standard Federated Learning for Time Series (e.g., [3]):** We move beyond treating clients as         │
# │ independent and identically distributed (i.i.d.) entities. By explicitly incorporating the shared spatial graph │
# │ topology into the model architecture and the federation process, we capture the inter-client correlations that  │
# │ are critical for understanding mobile network dynamics, a dimension largely ignored in standard FL.             │
# │ *   **Vs. Federated Graph Learning (e.g., [4]):** Our work is specifically tailored for the **spatiotemporal**  │
# │ anomaly detection problem. We focus on a unique setting where the graph is *homogeneous and shared* (the        │
# │ network topology), but the time-series features are heterogeneous and private. This contrasts with works on     │
# │ subgraph federation or vertically partitioned graphs. Furthermore, the integration of a dedicated imputation    │
# │ module addresses a key practical challenge (missing data) that is often overlooked in federated graph research. │
# │ *   **Holistic Integration:** The primary novelty lies in the co-design and tight integration of **federated    │
# │ learning**, **spatiotemporal graph modeling**, and **data imputation** into a single, end-to-end framework      │
# │ specifically for the mobile traffic domain. This integrated approach aims to solve the multifaceted challenges  │
# │ of privacy, spatial dependency, and data quality in a unified manner, which has not been comprehensively        │
# │ attempted in previous literature.                                                                               │
# │                                                                                                                 │
# │ ### Sources                                                                                                     │
# │ [1] A Deep Learning Approach for Anomaly Detection in Mobile Traffic:                                           │
# │ https://ieeexplore.ieee.org/abstract/document/9879879                                                           │
# │ [2] Connecting the Dots: Multivariate Time Series Forecasting with Graph Neural Networks:                       │
# │ https://arxiv.org/abs/2005.11650                                                                                │
# │ [3] Federated Learning for Intrusion Detection in IoT Networks: A Systematic Survey:                            │
# │ https://www.sciencedirect.com/science/article/pii/S1389128623001205                                             │
# │ [4] Federated Graph Neural Networks: Overview, Techniques and Challenges: https://arxiv.org/abs/2202.07256      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from rich.markdown import Markdown
Markdown(result["final_proposal"])
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃           A Research Proposal: Federated Spatiotemporal Anomaly Detection for Mobile Network Traffic            ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
#
#                                               1/ Research Motivation
#
# The exponential growth of mobile data traffic, driven by ubiquitous smart devices and emerging applications like
# IoT and AR/VR, presents significant challenges for network operators. Ensuring network reliability, security, and
# quality of service requires sophisticated monitoring systems capable of identifying anomalous behavior. Anomalies
# in mobile traffic can signal critical issues such as network failures, security breaches (e.g., DDoS attacks,
# botnet activity), unexpected congestion, or even large-scale public events.
#
# However, developing effective anomaly detection systems for mobile networks is inherently complex due to the unique
# characteristics of the data. Mobile traffic exhibits strong temporal patterns (daily, weekly, and seasonal cycles),
# intricate spatial dependencies influenced by network topology and user mobility, and is often subject to privacy
# regulations that restrict the centralization of sensitive user data. Furthermore, real-world data collection is
# prone to missing or incomplete records due to sensor failures or transmission errors. Current centralized detection
# models often struggle with these combined challenges, creating a pressing need for a novel, privacy-preserving, and
# robust framework that can leverage the full spatiotemporal structure of mobile data without compromising user
# privacy.
#
#
#                                          2/ Related Work and Research Gap
#
# Existing research on mobile traffic anomaly detection can be broadly categorized, each with notable limitations.
#
#  • Centralized Temporal Models: Traditional methods like ARIMA, LSTMs, and Transformers are applied to aggregated
#    time series data from network nodes [1]. While effective at capturing temporal patterns, they typically ignore
#    the spatial correlations between neighboring cells or base stations, leading to suboptimal detection of
#    spatially propagating anomalies.
#  • Spatiotemporal Graph Models: Recent advances employ Graph Neural Networks (GNNs) to model the network as a
#    graph, where nodes represent base stations and edges represent geographical or traffic-flow relationships.
#    Models like Graph WaveNet and MTGNN have shown promise in spatiotemporal forecasting [2]. However, their
#    application to anomaly detection usually requires centralized data collection, which conflicts with growing data
#    privacy concerns and regulations like GDPR.
#  • Federated Learning (FL) for Networking: FL has been explored for various network management tasks, including
#    intrusion detection and resource allocation [3]. Standard FL approaches (e.g., FedAvg) train a global model by
#    aggregating model updates from distributed nodes. While this preserves raw data locality, it is not inherently
#    designed for modeling the complex spatial dependencies between different participants (e.g., between telecom
#    operators or regional data centers).
#  • Federated Graph Learning: A nascent field explores training GNNs in a federated setting. Some approaches focus
#    on vertically partitioned graphs or subgraph federated learning [4]. However, applying these directly to mobile
#    networks is non-trivial. The spatial graph topology (which base station is adjacent to which) is often
#    non-private and can be shared, but the dynamic traffic features on those nodes are private and must remain
#    decentralized.
#
# Identified Research Gap: There is a conspicuous lack of a unified framework that simultaneously addresses: 1) the
# joint learning of temporal and spatial dependencies for accurate anomaly detection, 2) strict data privacy through
# federated learning, and 3) robustness to real-world data imperfections like missing values. Most prior work
# optimizes for one or two of these objectives, but not all three in an integrated manner tailored for mobile network
# data.
#
#
#                                      3/ Proposed Method and Research Questions
#
# Leveraging the researcher's expertise, we propose a novel framework: Federated Spatiotemporal Graph Imputation and
# Anomaly Detection (Fed-STGIAD). This framework is designed to perform accurate anomaly detection directly on
# decentralized, potentially incomplete mobile traffic data.
#
# Core Methodology: The proposed method consists of two co-designed components operating within a federated learning
# paradigm:
#
#  1 A Federated Spatiotemporal Graph Imputation Module: This module addresses missing data. Using a shared graph
#    structure (non-private network topology), each client (e.g., a regional server) trains a local GNN-based imputer
#    (e.g., using Graph Attention Networks or Diffusion Convolutional Networks) on its local time series. A central
#    server aggregates these local imputer models to create a global imputer that can infer missing values by
#    leveraging learned spatial correlations from across the federation, without sharing raw traffic data.
#  2 A Federated Spatiotemporal Anomaly Detector: This is the main detection model. It will be a graph-based
#    sequential model (e.g., a GNN coupled with a temporal convolutional network or a recurrent module). It will be
#    trained directly on the decentralized data. Crucially, to capture cross-client spatial dependencies—essential
#    for detecting anomalies that propagate across administrative boundaries—the federated aggregation step must be
#    enhanced. Instead of simple averaging (FedAvg), we will explore peer-to-peer federated learning strategies or
#    topology-aware model aggregation that weights updates based on the shared graph adjacency, aligning with the
#    researcher's expertise in peer-to-peer FL.
#
# Key Research Questions:
#
#  • RQ1: How can a graph neural network be effectively trained for spatiotemporal imputation in a federated setting
#    where the graph structure is global but node features are private and distributed?
#  • RQ2: What federated aggregation strategy (e.g., topology-aware averaging, peer-to-peer gossip protocols) most
#    effectively enables a global anomaly detection model to learn cross-client spatial dependencies while
#    maintaining privacy?
#  • RQ3: Does the joint optimization of imputation and anomaly detection in a federated framework lead to more
#    robust and accurate anomaly detection compared to treating these as separate, sequential tasks?
#  • RQ4: How does the proposed framework perform against state-of-the-art centralized and privacy-agnostic baselines
#    on real-world mobile traffic datasets with simulated missing data and injected anomalies?
#
#
#                                          4/ Contrast to Previous Research
#
# The proposed Fed-STGIAD framework fundamentally differs from and advances prior work in several key aspects:
#
#  • Vs. Centralized Spatiotemporal Models (e.g., [2]): Our approach eliminates the need for a central data
#    repository, offering a principled privacy-preserving alternative. This makes it viable in modern regulatory
#    environments and for cross-operator collaboration, which is infeasible for centralized models.
#  • Vs. Standard Federated Learning for Time Series (e.g., [3]): We move beyond treating clients as independent and
#    identically distributed (i.i.d.) entities. By explicitly incorporating the shared spatial graph topology into
#    the model architecture and the federation process, we capture the inter-client correlations that are critical
#    for understanding mobile network dynamics, a dimension largely ignored in standard FL.
#  • Vs. Federated Graph Learning (e.g., [4]): Our work is specifically tailored for the spatiotemporal anomaly
#    detection problem. We focus on a unique setting where the graph is homogeneous and shared (the network
#    topology), but the time-series features are heterogeneous and private. This contrasts with works on subgraph
#    federation or vertically partitioned graphs. Furthermore, the integration of a dedicated imputation module
#    addresses a key practical challenge (missing data) that is often overlooked in federated graph research.
#  • Holistic Integration: The primary novelty lies in the co-design and tight integration of federated learning,
#    spatiotemporal graph modeling, and data imputation into a single, end-to-end framework specifically for the
#    mobile traffic domain. This integrated approach aims to solve the multifaceted challenges of privacy, spatial
#    dependency, and data quality in a unified manner, which has not been comprehensively attempted in previous
#    literature.
#
#                                                       Sources
#
# [1] A Deep Learning Approach for Anomaly Detection in Mobile Traffic:
# https://ieeexplore.ieee.org/abstract/document/9879879 [2] Connecting the Dots: Multivariate Time Series Forecasting
# with Graph Neural Networks: https://arxiv.org/abs/2005.11650 [3] Federated Learning for Intrusion Detection in IoT
# Networks: A Systematic Survey: https://www.sciencedirect.com/science/article/pii/S1389128623001205 [4] Federated
# Graph Neural Networks: Overview, Techniques and Challenges: https://arxiv.org/abs/2202.07256
