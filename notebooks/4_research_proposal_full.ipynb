# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from IPython.display import Image, display
from llmkglitrev.agents.research_proposal_generator import proposal_generator_agent
from langchain_core.messages import HumanMessage, SystemMessage, BaseMessage
# Show the agent
display(Image(proposal_generator_agent.get_graph().draw_mermaid_png()))
# proposal_generator_agent.get_graph().print_ascii()

# %%
# Run the multi-agent supervisor agent
from utils import format_messages
from langchain_core.messages import HumanMessage
from llmkglitrev.samples import sample_1, sample_2
from llmkglitrev.agents.research_proposal_generator import proposal_generator_agent
from llmkglitrev.agents.states import AgentState, SupervisorState
# result = await proposal_generator_agent.ainvoke(
#     {"supervisor_messages": [HumanMessage(content=f"{sample_2}.")],
#     "research_topic": "Forecasting in Traffic/Network",
#     "raw_notes": [],
#     "notes": [],
#     "final_proposal":""})
result = await proposal_generator_agent.ainvoke(
    {"messages": [HumanMessage(content=f"{sample_2}.")]
    #  "research_topic": "Forecasting in Traffic/Network"
    }
)
# format_messages(result['final_proposal'])

# %%
format_messages(result["messages"])
# Out:
# ╭─────────────────────────────────────────────────── 🧑 Human ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │     Researcher A has expertise in time series, federated learning, machine learning. Here is his past research: │
# │     - Privacy-preserving federated learning for residential short-term load forecasting                         │
# │     - Secure federated learning for residential short term load forecasting                                     │
# │     - Bridging Smart Meter Gaps: A Benchmark of Statistical, Machine Learning and Time Series Foundation Models │
# │ for Data Imputation                                                                                             │
# │     - Towards a peer-to-peer residential short-term load forecasting with federated learning                    │
# │     - Spatiotemporal Graph Neural Networks in short term load forecasting: Does adding Graph Structure in       │
# │ Consumption Data Improve Predictions?                                                                           │
# │                                                                                                                 │
# │     He wants to collaborate and do research on anomaly detection in mobile traffic                              │
# │     Please propose a research idea that suits his past research and match with the topic he want to contributes │
# │ to                                                                                                              │
# │     .                                                                                                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────── 🧑 Human ────────────────────────────────────────────────────╮
# │ Here is the final proposal: # Research Proposal on Anomaly Detection in Mobile Traffic Using Federated Learning │
# │ and Spatiotemporal Models                                                                                       │
# │                                                                                                                 │
# │ ## Research Motivation                                                                                          │
# │                                                                                                                 │
# │ Anomaly detection in mobile network traffic is vital to ensure smooth network operations and enhance security.  │
# │ As mobile networks grow in complexity and scale, detecting anomalies becomes increasingly challenging.          │
# │ Researchers with expertise in time series analysis, federated learning, and graph neural networks are uniquely  │
# │ positioned to tackle these challenges. Using federated learning and spatiotemporal models offers a promising    │
# │ avenue for developing privacy-preserving anomaly detection frameworks suitable for distributed and dynamic      │
# │ mobile environments.                                                                                            │
# │                                                                                                                 │
# │ ## Related Work and Research Gap                                                                                │
# │                                                                                                                 │
# │ ### Related Work                                                                                                │
# │                                                                                                                 │
# │ The research landscape in privacy-preserving techniques for anomaly detection has seen significant advancements │
# │ with the integration of machine learning models and federated learning. Recent studies include:                 │
# │                                                                                                                 │
# │ - A hybrid ensemble model for network anomaly detection that emphasizes privacy and addresses imbalanced data   │
# │ sets by combining K-Nearest Neighbors (KNN), Support Vector Machines (SVM), XGBoost, and Artificial Neural      │
# │ Networks (ANN) [1].                                                                                             │
# │ - Federated learning frameworks that train AI models without compromising privacy, applied successfully across  │
# │ multiple domains such as medical diagnosis and financial fraud detection [2].                                   │
# │ - Exploration of spatiotemporal graph neural networks (GNNs) in traffic patterns which enhance anomaly          │
# │ detection by leveraging spatial and temporal data [3, 4].                                                       │
# │                                                                                                                 │
# │ ### Research Gap                                                                                                │
# │                                                                                                                 │
# │ Despite the progress, several key gaps remain:                                                                  │
# │                                                                                                                 │
# │ - **Cross-Operator Collaboration:** Existing literature focuses on single-operator scenarios, and there is      │
# │ limited work on developing cross-operator collaboration protocols for federated learning.                       │
# │ - **Secure Aggregation:** Secure aggregation methods are crucial for collaborative environments but lack        │
# │ standardization across mobile networks.                                                                         │
# │ - **Multi-Scale Temporal Modeling:** Current models inadequately integrate multi-scale temporal patterns into   │
# │ anomaly detection processes.                                                                                    │
# │ - **Real-Time & Edge Adaptive Algorithms:** There is a need for adaptive models that can operate in real time   │
# │ at the network edge, accommodating varying network conditions.                                                  │
# │                                                                                                                 │
# │ ## Proposed Methods                                                                                             │
# │                                                                                                                 │
# │ ### Critical Research Question                                                                                  │
# │                                                                                                                 │
# │ How can federated learning and spatiotemporal models be innovatively combined to create an efficient,           │
# │ privacy-preserving anomaly detection framework for mobile traffic that supports cross-operator collaboration    │
# │ and adapts to dynamic network scenarios?                                                                        │
# │                                                                                                                 │
# │ ### Proposed Approach                                                                                           │
# │                                                                                                                 │
# │ - **Federated Learning Framework:** Develop a novel federated learning architecture for cross-operator          │
# │ environments. This architecture should incorporate dynamic privacy-preserving mechanisms that adjust to threat  │
# │ levels and data sensitivity in real-time.                                                                       │
# │                                                                                                                 │
# │ - **Spatiotemporal Graph Neural Networks:** Utilize multi-scale temporal encoding within GNNs to capture both   │
# │ local and global patterns in network traffic. This hybrid approach would simultaneously perform load            │
# │ forecasting and anomaly detection.                                                                              │
# │                                                                                                                 │
# │ - **Secure Aggregation Protocols:** Design advanced secure aggregation methodologies tailored to mobile traffic │
# │ patterns. These protocols should ensure data integrity while facilitating seamless cross-operator               │
# │ collaboration.                                                                                                  │
# │                                                                                                                 │
# │ - **Edge-Based Learning Mechanism:** Implement adaptive algorithms capable of deploying at network edges,       │
# │ ensuring real-time anomaly detection and minimizing latency.                                                    │
# │                                                                                                                 │
# │ ## Contrast to Previous Research                                                                                │
# │                                                                                                                 │
# │ The proposed research differs from existing studies by:                                                         │
# │                                                                                                                 │
# │ - **Integrating Multi-Scale Temporal Patterns:** Unlike traditional models, this research emphasizes capturing  │
# │ both short-term and long-term traffic patterns using advanced spatiotemporal GNNs.                              │
# │                                                                                                                 │
# │ - **Dynamic Privacy Adjustments:** Introduces a novel approach where privacy adjustments are made dynamically   │
# │ based on current threat assessments, enhancing data protection and anomaly detection.                           │
# │                                                                                                                 │
# │ - **Cross-Operator Focus:** Shifts focus from single-operator scenarios to developing robust protocols for      │
# │ cross-operator environments, thus promoting collaborative security efforts within the mobile industry.          │
# │                                                                                                                 │
# │ - **Real-Time Edge Adaptation:** Prioritizes the development and implementation of algorithms that function     │
# │ efficiently at the network edge, offering real-time responsiveness and adaptability to changing network         │
# │ conditions.                                                                                                     │
# │                                                                                                                 │
# │ ### Sources                                                                                                     │
# │                                                                                                                 │
# │ [1] Privacy-Preserving Hybrid Ensemble Model for Network Anomaly Detection: https://arxiv.org/html/2502.09001v1 │
# │ [2] Federated Learning as a Privacy-Preserving Approach in Collaborative AI Model Training:                     │
# │ https://www.netguru.com/blog/federated-learning                                                                 │
# │ [3] Automatic Traffic Anomaly Detection on the Road Network:                                                    │
# │ https://onlinelibrary.wiley.com/doi/10.1155/2022/4222827                                                        │
# │ [4] Traffic Anomaly Detection based on Spatio-Temporal Hypergraph Convolutional Neural Network:                 │
# │ https://www.sciencedirect.com/science/article/abs/pii/S037843712400400X                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from rich.markdown import Markdown
Markdown(result["final_proposal"])
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Research Proposal on Anomaly Detection in Mobile Traffic Using Federated Learning and Spatiotemporal Models   ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
#
#                                                 Research Motivation
#
# Anomaly detection in mobile network traffic is vital to ensure smooth network operations and enhance security. As
# mobile networks grow in complexity and scale, detecting anomalies becomes increasingly challenging. Researchers
# with expertise in time series analysis, federated learning, and graph neural networks are uniquely positioned to
# tackle these challenges. Using federated learning and spatiotemporal models offers a promising avenue for
# developing privacy-preserving anomaly detection frameworks suitable for distributed and dynamic mobile
# environments.
#
#
#                                            Related Work and Research Gap
#
#                                                    Related Work
#
# The research landscape in privacy-preserving techniques for anomaly detection has seen significant advancements
# with the integration of machine learning models and federated learning. Recent studies include:
#
#  • A hybrid ensemble model for network anomaly detection that emphasizes privacy and addresses imbalanced data sets
#    by combining K-Nearest Neighbors (KNN), Support Vector Machines (SVM), XGBoost, and Artificial Neural Networks
#    (ANN) [1].
#  • Federated learning frameworks that train AI models without compromising privacy, applied successfully across
#    multiple domains such as medical diagnosis and financial fraud detection [2].
#  • Exploration of spatiotemporal graph neural networks (GNNs) in traffic patterns which enhance anomaly detection
#    by leveraging spatial and temporal data [3, 4].
#
#                                                    Research Gap
#
# Despite the progress, several key gaps remain:
#
#  • Cross-Operator Collaboration: Existing literature focuses on single-operator scenarios, and there is limited
#    work on developing cross-operator collaboration protocols for federated learning.
#  • Secure Aggregation: Secure aggregation methods are crucial for collaborative environments but lack
#    standardization across mobile networks.
#  • Multi-Scale Temporal Modeling: Current models inadequately integrate multi-scale temporal patterns into anomaly
#    detection processes.
#  • Real-Time & Edge Adaptive Algorithms: There is a need for adaptive models that can operate in real time at the
#    network edge, accommodating varying network conditions.
#
#
#                                                  Proposed Methods
#
#                                             Critical Research Question
#
# How can federated learning and spatiotemporal models be innovatively combined to create an efficient,
# privacy-preserving anomaly detection framework for mobile traffic that supports cross-operator collaboration and
# adapts to dynamic network scenarios?
#
#                                                  Proposed Approach
#
#  • Federated Learning Framework: Develop a novel federated learning architecture for cross-operator environments.
#    This architecture should incorporate dynamic privacy-preserving mechanisms that adjust to threat levels and data
#    sensitivity in real-time.
#  • Spatiotemporal Graph Neural Networks: Utilize multi-scale temporal encoding within GNNs to capture both local
#    and global patterns in network traffic. This hybrid approach would simultaneously perform load forecasting and
#    anomaly detection.
#  • Secure Aggregation Protocols: Design advanced secure aggregation methodologies tailored to mobile traffic
#    patterns. These protocols should ensure data integrity while facilitating seamless cross-operator collaboration.
#  • Edge-Based Learning Mechanism: Implement adaptive algorithms capable of deploying at network edges, ensuring
#    real-time anomaly detection and minimizing latency.
#
#
#                                            Contrast to Previous Research
#
# The proposed research differs from existing studies by:
#
#  • Integrating Multi-Scale Temporal Patterns: Unlike traditional models, this research emphasizes capturing both
#    short-term and long-term traffic patterns using advanced spatiotemporal GNNs.
#  • Dynamic Privacy Adjustments: Introduces a novel approach where privacy adjustments are made dynamically based on
#    current threat assessments, enhancing data protection and anomaly detection.
#  • Cross-Operator Focus: Shifts focus from single-operator scenarios to developing robust protocols for
#    cross-operator environments, thus promoting collaborative security efforts within the mobile industry.
#  • Real-Time Edge Adaptation: Prioritizes the development and implementation of algorithms that function
#    efficiently at the network edge, offering real-time responsiveness and adaptability to changing network
#    conditions.
#
#                                                       Sources
#
# [1] Privacy-Preserving Hybrid Ensemble Model for Network Anomaly Detection: https://arxiv.org/html/2502.09001v1
# [2] Federated Learning as a Privacy-Preserving Approach in Collaborative AI Model Training:
# https://www.netguru.com/blog/federated-learning
# [3] Automatic Traffic Anomaly Detection on the Road Network:
# https://onlinelibrary.wiley.com/doi/10.1155/2022/4222827
# [4] Traffic Anomaly Detection based on Spatio-Temporal Hypergraph Convolutional Neural Network:
# https://www.sciencedirect.com/science/article/abs/pii/S037843712400400X
