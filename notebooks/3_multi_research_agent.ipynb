# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from IPython.display import Image, display
from llmkglitrev.agents.research_supervisor import create_interactive_supervisor 
from langchain_core.messages import HumanMessage, SystemMessage, BaseMessage
# Show the agent
supervisor_agent = create_interactive_supervisor()
supervisor_agent.get_graph().print_ascii()
# supervisor_agent.get_graph().print_ascii()
# Out:
#                                   +-----------+
#                                   | __start__ |
#                                   +-----------+
#                                          *
#                                          *
#                                          *
#                                   +------------+
#                                   | supervisor |.
#                              .....+------------+ .....
#                         .....             .           .....
#                    .....                   .               .....
#                 ...                        .                    .....
# +--------------------+           +------------------+                ...
# | get_human_feedback |           | supervisor_tools |               ..
# +--------------------+           +------------------+             ..
#                                                  ...           ...
#                                                     ..       ..
#                                                       ..   ..
#                                                     +---------+
#                                                     | __end__ |
#                                                     +---------+

# %%
# Run the multi-agent supervisor agent
from utils import format_messages
from langchain_core.messages import HumanMessage
from llmkglitrev.agents.states import SupervisorState
from llmkglitrev.samples import sample_1, sample_2
# research_brief = """I want to identify and evaluate the coffee shops in San Francisco that are considered the best based specifically  
# on coffee quality. My research should focus on analyzing and comparing coffee shops within the San Francisco area, 
# using coffee quality as the primary criterion. I am open regarding methods of assessing coffee quality (e.g.,      
# expert reviews, customer ratings, specialty coffee certifications), and there are no constraints on ambiance,      
# location, wifi, or food options unless they directly impact perceived coffee quality. Please prioritize primary    
# sources such as the official websites of coffee shops, reputable third-party coffee review organizations (like     
# Coffee Review or Specialty Coffee Association), and prominent review aggregators like Google or Yelp where direct  
# customer feedback about coffee quality can be found. The study should result in a well-supported list or ranking of
# the top coffee shops in San Francisco, emphasizing their coffee quality according to the latest available data as  
# of July 2025."""

result = await supervisor_agent.ainvoke(SupervisorState(
    {"supervisor_messages": [HumanMessage(content=f"{sample_2}.")],
     "research_proposals":[],
     "notes": [],
     "research_topic": "Forecasting in Traffic/Network",
     "research_iterations":0,
     "got_human_feedback": False,
     "raw_notes":[],
     "pending_proposals": []}),
     config={"configurable": {"thread_id": "test-1"}}  # Required for checkpointer
)
format_messages(result['supervisor_messages'])
# Out:
# ======================================================================
# 🔍 PROPOSED RESEARCH DIRECTIONS:
# ======================================================================
#
# 1. Researcher A has strong expertise in:
# 1. Time series analysis and forecasting (load forecasting, smart meter data)
# 2. Federated learning with privacy/security focus
# 3. Graph neural networks for spatiotemporal data
# 4. Data imputation techniques for time series gaps
#
# They want to work on anomaly detection in mobile traffic. This is a perfect match because:
# - Mobile traffic data is inherently time series data with temporal patterns
# - Mobile networks generate massive distributed data across devices/regions
# - Privacy concerns exist with mobile traffic data
# - Anomalies could be detected using similar techniques to load forecasting
#
# Potential research directions:
# 1. Federated learning for privacy-preserving anomaly detection in mobile traffic
# 2. Time series foundation models for mobile traffic anomaly detection
# 3. Graph-based approaches for network-wide anomaly detection
# 4. Data imputation techniques for handling missing mobile traffic data during anomaly detection
#
# I should delegate research to explore these connections more deeply.
#
# ======================================================================
# ╭─────────────────────────────────────────────────── 🧑 Human ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │     Researcher A has expertise in time series, federated learning, machine learning. Here is his past research: │
# │     - Privacy-preserving federated learning for residential short-term load forecasting                         │
# │     - Secure federated learning for residential short term load forecasting                                     │
# │     - Bridging Smart Meter Gaps: A Benchmark of Statistical, Machine Learning and Time Series Foundation Models │
# │ for Data Imputation                                                                                             │
# │     - Towards a peer-to-peer residential short-term load forecasting with federated learning                    │
# │     - Spatiotemporal Graph Neural Networks in short term load forecasting: Does adding Graph Structure in       │
# │ Consumption Data Improve Predictions?                                                                           │
# │                                                                                                                 │
# │     He wants to collaborate and do research on anomaly detection in mobile traffic                              │
# │     Please propose a research idea that suits his past research and match with the topic he want to contributes │
# │ to                                                                                                              │
# │     .                                                                                                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │ I'll help you develop a research idea that bridges Researcher A's expertise in time series, federated learning, │
# │ and machine learning with their interest in anomaly detection in mobile traffic. Let me start by thinking       │
# │ through the approach.                                                                                           │
# │                                                                                                                 │
# │ 🔧 Tool Call: supervisor_think_tool                                                                             │
# │    Args: {                                                                                                      │
# │   "reflection": "Researcher A has strong expertise in:\n1. Time series analysis and forecasting (load           │
# │ forecasting, smart meter data)\n2. Federated learning with privacy/security focus\n3. Graph neural networks for │
# │ spatiotemporal data\n4. Data imputation techniques for time series gaps\n\nThey want to work on anomaly         │
# │ detection in mobile traffic. This is a perfect match because:\n- Mobile traffic data is inherently time series  │
# │ data with temporal patterns\n- Mobile networks generate massive distributed data across devices/regions\n-      │
# │ Privacy concerns exist with mobile traffic data\n- Anomalies could be detected using similar techniques to load │
# │ forecasting\n\nPotential research directions:\n1. Federated learning for privacy-preserving anomaly detection   │
# │ in mobile traffic\n2. Time series foundation models for mobile traffic anomaly detection\n3. Graph-based        │
# │ approaches for network-wide anomaly detection\n4. Data imputation techniques for handling missing mobile        │
# │ traffic data during anomaly detection\n\nI should delegate research to explore these connections more deeply."  │
# │ }                                                                                                               │
# │    ID: call_00_2LEYfuaUuLg3X2MI6tjXAzCi                                                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
