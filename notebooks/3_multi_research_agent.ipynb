# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from IPython.display import Image, display
from llmkglitrev.agents.research_supervisor import supervisor_agent 
from langchain_core.messages import HumanMessage, SystemMessage, BaseMessage
# Show the agent
display(Image(supervisor_agent.get_graph().draw_mermaid_png()))
# supervisor_agent.get_graph().print_ascii()

# %%
# Run the multi-agent supervisor agent
from utils import format_messages
from langchain_core.messages import HumanMessage
from llmkglitrev.agents.states import SupervisorState
from llmkglitrev.samples import sample_1, sample_2
# research_brief = """I want to identify and evaluate the coffee shops in San Francisco that are considered the best based specifically  
# on coffee quality. My research should focus on analyzing and comparing coffee shops within the San Francisco area, 
# using coffee quality as the primary criterion. I am open regarding methods of assessing coffee quality (e.g.,      
# expert reviews, customer ratings, specialty coffee certifications), and there are no constraints on ambiance,      
# location, wifi, or food options unless they directly impact perceived coffee quality. Please prioritize primary    
# sources such as the official websites of coffee shops, reputable third-party coffee review organizations (like     
# Coffee Review or Specialty Coffee Association), and prominent review aggregators like Google or Yelp where direct  
# customer feedback about coffee quality can be found. The study should result in a well-supported list or ranking of
# the top coffee shops in San Francisco, emphasizing their coffee quality according to the latest available data as  
# of July 2025."""

result = await supervisor_agent.ainvoke(SupervisorState(
    {"supervisor_messages": [HumanMessage(content=f"{sample_2}.")],
     "research_proposals":[],
     "notes": [],
     "research_topic": "Forecasting in Traffic/Network",
     "research_iterations":0,
     "raw_notes":[]}))
format_messages(result['supervisor_messages'])
# Out:
# ╭─────────────────────────────────────────────────── 🧑 Human ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │     Researcher A has expertise in time series, federated learning, machine learning. Here is his past research: │
# │     - Privacy-preserving federated learning for residential short-term load forecasting                         │
# │     - Secure federated learning for residential short term load forecasting                                     │
# │     - Bridging Smart Meter Gaps: A Benchmark of Statistical, Machine Learning and Time Series Foundation Models │
# │ for Data Imputation                                                                                             │
# │     - Towards a peer-to-peer residential short-term load forecasting with federated learning                    │
# │     - Spatiotemporal Graph Neural Networks in short term load forecasting: Does adding Graph Structure in       │
# │ Consumption Data Improve Predictions?                                                                           │
# │                                                                                                                 │
# │     He wants to collaborate and do research on anomaly detection in mobile traffic                              │
# │     Please propose a research idea that suits his past research and match with the topic he want to contributes │
# │ to                                                                                                              │
# │     .                                                                                                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ 🔧 Tool Call: supervisor_think_tool                                                                             │
# │    Args: {                                                                                                      │
# │   "reflection": "Looking at this request, I need to analyze Researcher A's expertise and propose research ideas │
# │ that bridge their background with anomaly detection in mobile traffic.\n\nResearcher A's expertise areas:\n-    │
# │ Time series forecasting (especially short-term load forecasting)\n- Federated learning (privacy-preserving and  │
# │ secure variants)\n- Machine learning and statistical methods\n- Graph neural networks for spatiotemporal        │
# │ data\n- Data imputation techniques\n- Residential energy consumption patterns\n\nThe target topic is \"anomaly  │
# │ detection in mobile traffic\" - this involves:\n- Mobile network data patterns\n- Traffic anomaly               │
# │ identification\n- Network performance monitoring\n- Security and privacy concerns in mobile networks\n\nI can   │
# │ see clear opportunities for parallel research exploration:\n1. Technical methods perspective: How can federated │
# │ learning be applied to mobile traffic anomaly detection, leveraging his federated learning expertise?\n2.       │
# │ Application domains perspective: What are the specific challenges and opportunities in mobile traffic anomaly   │
# │ detection that align with his time series and spatiotemporal modeling experience?\n\nThese two research         │
# │ directions are independent and can be explored simultaneously. This will give me comprehensive coverage of both │
# │ the methodological innovation potential and the domain-specific applications."                                  │
# │ }                                                                                                               │
# │    ID: toolu_01MTQhs8At7BTrrmNswYx9QJ                                                                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── 🔧 Tool Output ─────────────────────────────────────────────────╮
# │ Reflection recorded: Looking at this request, I need to analyze Researcher A's expertise and propose research   │
# │ ideas that bridge their background with anomaly detection in mobile traffic.                                    │
# │                                                                                                                 │
# │ Researcher A's expertise areas:                                                                                 │
# │ - Time series forecasting (especially short-term load forecasting)                                              │
# │ - Federated learning (privacy-preserving and secure variants)                                                   │
# │ - Machine learning and statistical methods                                                                      │
# │ - Graph neural networks for spatiotemporal data                                                                 │
# │ - Data imputation techniques                                                                                    │
# │ - Residential energy consumption patterns                                                                       │
# │                                                                                                                 │
# │ The target topic is "anomaly detection in mobile traffic" - this involves:                                      │
# │ - Mobile network data patterns                                                                                  │
# │ - Traffic anomaly identification                                                                                │
# │ - Network performance monitoring                                                                                │
# │ - Security and privacy concerns in mobile networks                                                              │
# │                                                                                                                 │
# │ I can see clear opportunities for parallel research exploration:                                                │
# │ 1. Technical methods perspective: How can federated learning be applied to mobile traffic anomaly detection,    │
# │ leveraging his federated learning expertise?                                                                    │
# │ 2. Application domains perspective: What are the specific challenges and opportunities in mobile traffic        │
# │ anomaly detection that align with his time series and spatiotemporal modeling experience?                       │
# │                                                                                                                 │
# │ These two research directions are independent and can be explored simultaneously. This will give me             │
# │ comprehensive coverage of both the methodological innovation potential and the domain-specific applications.    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ 🔧 Tool Call: ConductResearch                                                                                   │
# │    Args: {                                                                                                      │
# │   "research_topic": "Federated learning applications in mobile traffic anomaly detection: Research current      │
# │ methods, challenges, and opportunities for applying privacy-preserving federated learning techniques to detect  │
# │ anomalies in mobile network traffic data. Focus on how federated learning can address privacy concerns while    │
# │ enabling collaborative anomaly detection across multiple mobile network operators or base stations. Examine     │
# │ existing federated learning frameworks for anomaly detection and identify gaps where techniques from            │
# │ residential load forecasting could be adapted."                                                                 │
# │ }                                                                                                               │
# │    ID: toolu_01YUQBFET67tokSD4h8eM1S5                                                                           │
# │                                                                                                                 │
# │ 🔧 Tool Call: ConductResearch                                                                                   │
# │    Args: {                                                                                                      │
# │   "research_topic": "Time series and spatiotemporal modeling approaches for mobile traffic anomaly detection:   │
# │ Investigate how time series forecasting methods and graph neural networks can be applied to mobile traffic      │
# │ anomaly detection. Research the similarities and differences between residential energy consumption patterns    │
# │ and mobile network traffic patterns. Explore opportunities for adapting short-term load forecasting techniques, │
# │ data imputation methods, and spatiotemporal graph neural networks to identify anomalous patterns in mobile      │
# │ network data across different cell towers and geographic regions."                                              │
# │ }                                                                                                               │
# │    ID: toolu_01JApTto9cJ9L6SgdP2rbHQa                                                                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── 🔧 Tool Output ─────────────────────────────────────────────────╮
# │ **List of Queries and Tool Calls Made**                                                                         │
# │                                                                                                                 │
# │ 1. Search for federated learning applications in mobile network anomaly detection and privacy-preserving        │
# │ frameworks:                                                                                                     │
# │    - Query: "federated learning mobile network traffic anomaly detection privacy preserving recent research     │
# │ challenges"                                                                                                     │
# │                                                                                                                 │
# │ 2. Search for residential load forecasting techniques for potential adaptation in federated learning            │
# │ frameworks:                                                                                                     │
# │    - Query: "residential load forecasting techniques machine learning federated learning applications recent    │
# │ advances"                                                                                                       │
# │                                                                                                                 │
# │ **Complete Research Plans**                                                                                     │
# │                                                                                                                 │
# │ Research Plan 1:                                                                                                │
# │ - **Motivation**: Traditional centralized anomaly detection systems face challenges related to data privacy and │
# │ scalability, making federated learning a promising alternative (GuardianAI, ScienceDirect).                     │
# │ - **Research Gap**: Limited work on combining federated learning with specific mobile network traffic patterns  │
# │ and the need for addressing system heterogeneity in mobile networks (Privacy Preserving Federated Anomaly       │
# │ Detection, ScienceDirect).                                                                                      │
# │ - **Methods**: Explore federated learning architectures discussed in "Federated Learning: A Survey on           │
# │ Privacy-Preserving Collaborative". Implement pattern recognition techniques from residential load forecasting   │
# │ into federated learning frameworks for mobile traffic anomaly detection.                                        │
# │ - **Results**: Federated Learning enables privacy-preserving collaborative training across distributed data     │
# │ sources by transmitting model updates instead of raw data. Applications exist in IoT edge computing and mobile  │
# │ devices, yet issues like scalability and fairness remain open, guiding future research directions (Federated    │
# │ Learning, arXiv).                                                                                               │
# │ - **Conclusion**: Integrating pattern recognition techniques from the residential load domain could advance     │
# │ federated learning applications in mobile traffic anomaly detection.                                            │
# │                                                                                                                 │
# │ Sources for Plan 1:                                                                                             │
# │ 1. "GuardianAI: Privacy-preserving federated anomaly detection with ..." - ScienceDirect                        │
# │ 2. "Privacy Preserving Federated Anomaly Detection in IoT Edge ..." - ScienceDirect                             │
# │ 3. "Federated Learning: A Survey on Privacy-Preserving Collaborative ..." - arXiv                               │
# │                                                                                                                 │
# │ Research Plan 2:                                                                                                │
# │ - **Motivation**: AI-based forecasting techniques, with recent advances in model architectures and learning,    │
# │ show promise for enhancing federated learning models in new application domains (AI-Driven Household            │
# │ Electricity Load Forecasting, Preprints.org).                                                                   │
# │ - **Research Gap**: Adaptation of machine learning methods specific to short-term residential load forecasting  │
# │ for traffic anomaly detection in mobile networks, addressing heterogeneity, and non-IID data issues (Federated  │
# │ Learning for Short-Term Residential Load Forecasting, ResearchGate).                                            │
# │ - **Methods**: Implement modified federated learning algorithms, handle temporal patterns, and seasonal         │
# │ variations within mobile networks. Develop hybrid models through the fusion of anomaly detection and load       │
# │ forecasting strategies.                                                                                         │
# │ - **Results**: New modified federated learning algorithms have been shown to effectively forecast residential   │
# │ loads. These advances could enhance the federated learning framework for mobile anomaly detection by            │
# │ incorporating similar approaches (Residential Load Forecasting Using Modified Federated Learning,               │
# │ ResearchGate).                                                                                                  │
# │ - **Conclusion**: The integration of residential load forecasting techniques can lead to hybrid federated       │
# │ models that improve privacy, accuracy, and learning efficiency in mobile network anomaly detection.             │
# │                                                                                                                 │
# │ Sources for Plan 2:                                                                                             │
# │ 1. "AI-Driven Household Electricity Load Forecasting" - Preprints.org                                           │
# │ 2. "Federated Learning for Short-Term Residential Load Forecasting" - ResearchGate                              │
# │ 3. "Residential Load Forecasting Using Modified Federated Learning ..." - ResearchGate                          │
# │                                                                                                                 │
# │ **List of All Relevant Sources**                                                                                │
# │                                                                                                                 │
# │ 1. "GuardianAI: Privacy-preserving federated anomaly detection with ..." - ScienceDirect                        │
# │    - URL: [ScienceDirect Source](https://www.sciencedirect.com/science/article/pii/S2590005625000086)           │
# │                                                                                                                 │
# │ 2. "Privacy Preserving Federated Anomaly Detection in IoT Edge ..." - ScienceDirect                             │
# │    - URL: [ScienceDirect Source](https://www.sciencedirect.com/org/science/article/pii/S1546221825006575)       │
# │                                                                                                                 │
# │ 3. "Federated Learning: A Survey on Privacy-Preserving Collaborative ..." - arXiv                               │
# │    - URL: (https://arxiv.org/html/2504.17703v3)                                                                 │
# │                                                                                                                 │
# │ 4. "AI-Driven Household Electricity Load Forecasting" - Preprints.org                                           │
# │    - URL: [Preprints.org Source](https://www.preprints.org/manuscript/202508.0799/v1)                           │
# │                                                                                                                 │
# │ 5. "Federated Learning for Short-Term Residential Load Forecasting" - ResearchGate                              │
# │    - URL: [ResearchGate                                                                                         │
# │ Source](https://www.researchgate.net/publication/363497741_Federated_Learning_for_Short-term_Residential_Load_F │
# │ orecasting)                                                                                                     │
# │                                                                                                                 │
# │ 6. "Residential Load Forecasting Using Modified Federated Learning ..." - ResearchGate                          │
# │    - URL: [ResearchGate                                                                                         │
# │ Source](https://www.researchgate.net/publication/370137761_Residential_Load_Forecasting_Using_Modified_Federate │
# │ d_Learning_Algorithm)                                                                                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── 🔧 Tool Output ─────────────────────────────────────────────────╮
# │ **List of Queries and Tool Calls Made**                                                                         │
# │                                                                                                                 │
# │ 1. Search Query: Recent advances in mobile network traffic anomaly detection using time series forecasting and  │
# │ graph neural networks research papers 2023                                                                      │
# │ 2. Search Query: Residential energy consumption patterns short term load forecasting techniques spatiotemporal  │
# │ analysis recent research                                                                                        │
# │ 3. Search Query: Mobile network traffic patterns characteristics spatiotemporal analysis cell towers research   │
# │ 2023 2024                                                                                                       │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ **Complete Research Plans**                                                                                     │
# │                                                                                                                 │
# │ Title: "STAR-MobileNet: Spatiotemporal Anomaly Recognition for Mobile Networks using Cross-Domain Knowledge     │
# │ Transfer and Hybrid Deep Learning"                                                                              │
# │                                                                                                                 │
# │ Research Objectives:                                                                                            │
# │ 1. Develop a novel framework for mobile traffic anomaly detection by adapting successful techniques from        │
# │ residential energy forecasting.                                                                                 │
# │ 2. Create new methods for handling spatial uncertainty in mobile network traffic prediction.                    │
# │ 3. Design and implement a hybrid architecture combining GNNs, traditional time series methods, and uncertainty  │
# │ quantification.                                                                                                 │
# │                                                                                                                 │
# │ **Research Plan:**                                                                                              │
# │                                                                                                                 │
# │ **Phase 1: Data Collection and Preliminary Analysis (3-4 months)**                                              │
# │ - Collect mobile network traffic data from multiple cell towers across different geographic regions.            │
# │ - Gather residential energy consumption data for comparative analysis.                                          │
# │ - Perform exploratory data analysis to identify common patterns and differences.                                │
# │ - Document temporal and spatial characteristics of both domains.                                                │
# │                                                                                                                 │
# │ **Phase 2: Framework Development (4-5 months)**                                                                 │
# │ 1. **Adapt Residential Energy Forecasting Techniques**                                                          │
# │    - Implement bipartite graph structures for cell tower relationships.                                         │
# │    - Modify seasonal pattern detection methods for mobile traffic.                                              │
# │    - Develop cross-domain feature extraction techniques.                                                        │
# │                                                                                                                 │
# │ 2. **Enhanced Spatial Uncertainty Handling**                                                                    │
# │    - Design new spatial uncertainty quantification methods.                                                     │
# │    - Develop adaptive graph formation techniques.                                                               │
# │    - Implement spatial reliability scoring mechanisms.                                                          │
# │                                                                                                                 │
# │ 3. **Hybrid Architecture Development**                                                                          │
# │    - Integrate GNN components with traditional time series methods.                                             │
# │    - Implement transformer-based temporal modeling.                                                             │
# │    - Develop ensemble learning approach combining multiple models.                                              │
# │                                                                                                                 │
# │ **Phase 3: Model Implementation and Testing (3-4 months)**                                                      │
# │ - Implement the proposed framework using PyTorch/TensorFlow.                                                    │
# │ - Develop baseline models for comparison.                                                                       │
# │ - Create synthetic anomaly datasets for testing.                                                                │
# │ - Perform comprehensive evaluation using multiple metrics.                                                      │
# │                                                                                                                 │
# │ **Phase 4: Validation and Optimization (2-3 months)**                                                           │
# │ - Validate results on real-world datasets.                                                                      │
# │ - Optimize model parameters and architecture.                                                                   │
# │ - Conduct ablation studies.                                                                                     │
# │ - Compare with state-of-the-art methods.                                                                        │
# │                                                                                                                 │
# │ **Phase 5: Documentation and Publication (2-3 months)**                                                         │
# │ - Document methodology and findings.                                                                            │
# │ - Prepare research paper(s).                                                                                    │
# │ - Create open-source implementation.                                                                            │
# │ - Develop case studies and examples.                                                                            │
# │                                                                                                                 │
# │ Innovation Aspects:                                                                                             │
# │ 1. Novel cross-domain knowledge transfer framework.                                                             │
# │ 2. New methods for handling spatial uncertainty.                                                                │
# │ 3. Hybrid architecture combining multiple successful approaches.                                                │
# │ 4. Adaptive graph formation techniques.                                                                         │
# │                                                                                                                 │
# │ Expected Contributions:                                                                                         │
# │ 1. A new framework for mobile network traffic anomaly detection.                                                │
# │ 2. Improved methods for handling spatial uncertainty.                                                           │
# │ 3. Cross-domain knowledge transfer techniques.                                                                  │
# │ 4. Open-source implementation and datasets.                                                                     │
# │ 5. Comprehensive empirical evaluation and comparison.                                                           │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ **List of All Relevant Sources (with citations in the proposal)**                                               │
# │                                                                                                                 │
# │ 1. SOURCE 1: Using Graph Neural Networks to Improve Network Traffic Anomaly. URL:                               │
# │ https://www.researchgate.net/publication/392811926_Using_Graph_Neural_Networks_to_Improve_Network_Traffic_Anoma │
# │ ly_Detection_Performance                                                                                        │
# │                                                                                                                 │
# │ 2. SOURCE 2: Awesome Graph Neural Networks for Time Series Analysis (GNN4TS). URL:                              │
# │ https://github.com/KimMeen/Awesome-GNN4TS                                                                       │
# │                                                                                                                 │
# │ 3. SOURCE 3: Advanced Anomaly Detection in Mobile Networks: A Hybrid ..... URL:                                 │
# │ https://www.researchgate.net/publication/393677409_Advanced_Anomaly_Detection_in_Mobile_Networks_A_Hybrid_Appro │
# │ ach_Based_on_Statistical_and_Machine_Learning_Techniques                                                        │
# │                                                                                                                 │
# │ 4. SOURCE 4: Spatial-Temporal Residential Short-Term Load Forecasting via.... URL:                              │
# │ https://www.researchgate.net/publication/352873481_Spatial-Temporal_Residential_Short-Term_Load_Forecasting_via │
# │ _Graph_Neural_Networks                                                                                          │
# │                                                                                                                 │
# │ 5. SOURCE 5: A short-term residential load forecasting framework based on.... URL:                              │
# │ https://www.researchgate.net/publication/394770755_A_short-term_residential_load_forecasting_framework_based_on │
# │ _dynamic_spatio-temporal_graph_neural_networks                                                                  │
# │                                                                                                                 │
# │ 6. SOURCE 6: Spatiotemporal Graph Neural Networks in short-term load forecasting. URL:                          │
# │ https://arxiv.org/html/2502.12175v1                                                                             │
# │                                                                                                                 │
# │ 7. SOURCE 7: Forecasting of mobile network traffic and spatio–temporal analysis.... URL:                        │
# │ https://www.researchgate.net/publication/376081395_Forecasting_of_mobile_network_traffic_and_spatio-temporal_an │
# │ alysis_using_modLSTM                                                                                            │
# │                                                                                                                 │
# │ 8. SOURCE 8: Understanding the spatial uncertainty of mobile phone network data.... URL:                        │
# │ https://www.sciencedirect.com/science/article/abs/pii/S0198971524000590                                         │
# │                                                                                                                 │
# │ 9. SOURCE 9: Spatiotemporal Mobile Traffic Forecasting Using AutoML, TimeGPT.... URL:                           │
# │ https://www.mdpi.com/2073-431X/14/7/268                                                                         │
# │                                                                                                                 │
# │ These findings and resources provide a comprehensive answer to the research topic around applying time series   │
# │ and spatiotemporal modeling for anomaly detection in mobile networks by recognizing opportunities for           │
# │ cross-domain knowledge transfer.                                                                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ 🔧 Tool Call: supervisor_think_tool                                                                             │
# │    Args: {                                                                                                      │
# │   "reflection": "Excellent! I now have comprehensive research findings from both parallel agents that provide a │
# │ solid foundation for proposing research ideas. Let me analyze the key findings:\n\n**From Agent 1 (Federated    │
# │ Learning perspective):**\n- Found that federated learning is promising for mobile network anomaly detection due │
# │ to privacy concerns\n- Identified research gaps in addressing system heterogeneity and non-IID data issues in   │
# │ mobile networks\n- Discovered existing work on privacy-preserving federated anomaly detection but limited       │
# │ application to mobile traffic specifically\n- Found evidence that residential load forecasting techniques can   │
# │ be adapted to federated learning frameworks\n\n**From Agent 2 (Time Series & Spatiotemporal perspective):**\n-  │
# │ Identified opportunities for cross-domain knowledge transfer from residential energy to mobile networks\n-      │
# │ Found specific techniques like spatiotemporal graph neural networks that can be adapted\n- Discovered research  │
# │ on spatial uncertainty in mobile network data - a unique challenge not present in residential energy\n- Found   │
# │ evidence of recent work on mobile traffic forecasting using modified LSTM and spatiotemporal analysis\n\n**Key  │
# │ Research Opportunities:**\n1. **Privacy-Preserving Federated Anomaly Detection**: Combining Researcher A's      │
# │ federated learning expertise with mobile traffic anomaly detection\n2. **Cross-Domain Knowledge Transfer**:     │
# │ Adapting residential load forecasting techniques to mobile network patterns\n3. **Spatiotemporal Mobile Traffic │
# │ Modeling**: Using GNNs and time series methods for anomaly detection\n4. **Hybrid Federated-Spatiotemporal      │
# │ Approach**: A novel combination of both perspectives\n\nI now have sufficient information to propose concrete,  │
# │ feasible research ideas that align with Researcher A's expertise and the target domain. The research findings   │
# │ provide strong evidence for the feasibility and novelty of these approaches."                                   │
# │ }                                                                                                               │
# │    ID: toolu_01CWuhduhp8m4cwSouAQgdHg                                                                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
